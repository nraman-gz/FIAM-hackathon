# %%
import pandas as pd
import numpy as np
import warnings, os
warnings.simplefilter("ignore")

df = pd.read_csv("processed_sentiment.csv")
from datetime import datetime
from dateutil.relativedelta import relativedelta


def add_months(date_int, months):
    # Convert string to datetime
    date_obj = datetime.strptime(str(date_int), "%Y%m%d")
    
    # Add 3 months
    new_date = date_obj + relativedelta(months=months)
    
    # Convert back to string in yyyymmdd format
    new_date_str = new_date.strftime("%Y%m%d")
    
    return int(new_date_str)
stock_df = pd.read_csv("ret_sample.csv")

# %%
df = pd.read_csv("processed_sentiment.csv")
df['delta_score'].corr(df['ret_1_0'])
df["date"] = pd.to_datetime(df["date"])
df["date"] = df["date"].dt.strftime("%Y%m%d")

# %%
def monthly_strategy(month,stock_df):
    initial_investment = 10000
    cash_spent = 0
    total_cash = 0
    count = 0
    signals = df.sort_values('date')
    signals['date'] = signals['date'].astype(int)
    signals = signals[(signals['date'] > int(f"{month}01")) & (signals['date'] < int(f"{month+1}01"))]
    stock_df = stock_df[(stock_df['date'] > int(f"{month}01")) & (stock_df['date'] < int(f"{month+1}01"))]

    for row in signals.itertuples():
        initial_investment = 10000
        if row.delta_score > 0.1:
            initial_investment = initial_investment * (1 + row.ret_1_0)
            if str(initial_investment)=="nan":
                continue
            total_cash += initial_investment
            cash_spent += 10000
            count += 1
            #print(f"Bought {row.gvkey} at {row.prc} on {row.date}, new investment value: {initial_investment} ")
    #print(f"Month: {month}, total cash: {round(total_cash,2)}, cash spent: {cash_spent}, count: {count}")
    if cash_spent == 0:
        print(f"Month: {month}, total cash: {round(total_cash,2)}, cash spent: {cash_spent}, count: {count} return 0")
        return 0
    print(f"Month: {month}, total cash: {round(total_cash,2)}, cash spent: {cash_spent}, count: {count}, return {round((total_cash - cash_spent) / cash_spent * 100,2)}%")
    return (total_cash - cash_spent) / cash_spent

start_date = datetime(2010, 1, 1)
end_date = datetime(2024, 12, 30)
monthly_periods = pd.period_range(start=start_date, end=end_date, freq='M')
initial = 1_000_000
for i in list(monthly_periods):
    month = int(i.to_timestamp().to_pydatetime().strftime("%Y%m%d")[0:6])
    initial = initial * float (monthly_strategy(month, stock_df) + 1)
    #print(month,"return", monthly_strategy(month, stock_df))
    #break
print("Final cash after all months:", initial)
# Out:
# Month: 201001, total cash: 176725.92, cash spent: 170000, count: 17, return 3.96%
# Month: 201002, total cash: 1104097.88, cash spent: 1150000, count: 115, return -3.99%
# Month: 201003, total cash: 395047.29, cash spent: 380000, count: 38, return 3.96%
# Month: 201004, total cash: 598210.33, cash spent: 550000, count: 55, return 8.77%
# Month: 201005, total cash: 1502374.9, cash spent: 1430000, count: 143, return 5.06%
# Month: 201006, total cash: 147702.47, cash spent: 160000, count: 16, return -7.69%
# Month: 201007, total cash: 338021.53, cash spent: 370000, count: 37, return -8.64%
# Month: 201008, total cash: 1170963.56, cash spent: 1070000, count: 107, return 9.44%
# Month: 201009, total cash: 120709.51, cash spent: 130000, count: 13, return -7.15%
# Month: 201010, total cash: 190337.66, cash spent: 170000, count: 17, return 11.96%
# Month: 201011, total cash: 689727.35, cash spent: 660000, count: 66, return 4.5%
# Month: 201012, total cash: 115798.15, cash spent: 110000, count: 11, return 5.27%
# Month: 201101, total cash: 120224.67, cash spent: 110000, count: 11, return 9.3%
# Month: 201408, total cash: 707198.29, cash spent: 740000, count: 74, return -4.43%
# Month: 201409, total cash: 169642.12, cash spent: 160000, count: 16, return 6.03%
# Month: 201410, total cash: 288109.43, cash spent: 300000, count: 30, return -3.96%
# Month: 201411, total cash: 611670.08, cash spent: 590000, count: 59, return 3.67%
# Month: 201412, total cash: 115026.22, cash spent: 110000, count: 11, return 4.57%
# Month: 201501, total cash: 71206.84, cash spent: 70000, count: 7, return 1.72%
# Month: 201502, total cash: 667490.36, cash spent: 690000, count: 69, return -3.26%
# Month: 201503, total cash: 287618.38, cash spent: 270000, count: 27, return 6.53%
# Month: 201504, total cash: 187346.33, cash spent: 190000, count: 19, return -1.4%
# Month: 201505, total cash: 748134.76, cash spent: 750000, count: 75, return -0.25%
# Month: 201506, total cash: 136950.88, cash spent: 130000, count: 13, return 5.35%
# Month: 201507, total cash: 435953.25, cash spent: 440000, count: 44, return -0.92%
# Month: 201508, total cash: 483620.61, cash spent: 490000, count: 49, return -1.3%
# Month: 201509, total cash: 87047.92, cash spent: 90000, count: 9, return -3.28%
# Month: 201510, total cash: 286804.62, cash spent: 300000, count: 30, return -4.4%
# Month: 201511, total cash: 424425.46, cash spent: 390000, count: 39, return 8.83%
# Month: 201512, total cash: 112812.65, cash spent: 110000, count: 11, return 2.56%
# Month: 201601, total cash: 67695.15, cash spent: 70000, count: 7, return -3.29%
# Month: 201602, total cash: 978369.3, cash spent: 1050000, count: 105, return -6.82%
# Month: 201603, total cash: 159201.49, cash spent: 160000, count: 16, return -0.5%
# Month: 201604, total cash: 341248.36, cash spent: 310000, count: 31, return 10.08%
# Month: 201605, total cash: 622676.67, cash spent: 610000, count: 61, return 2.08%
# Month: 201606, total cash: 108346.84, cash spent: 110000, count: 11, return -1.5%
# Month: 201607, total cash: 333828.37, cash spent: 330000, count: 33, return 1.16%
# Month: 201608, total cash: 687228.2, cash spent: 640000, count: 64, return 7.38%
# Month: 201609, total cash: 122222.98, cash spent: 120000, count: 12, return 1.85%
# Month: 201610, total cash: 265793.77, cash spent: 260000, count: 26, return 2.23%
# Month: 201611, total cash: 451442.32, cash spent: 470000, count: 47, return -3.95%
# Month: 201612, total cash: 121848.1, cash spent: 110000, count: 11, return 10.77%
# Month: 201701, total cash: 39245.28, cash spent: 40000, count: 4, return -1.89%
# Month: 201702, total cash: 873355.48, cash spent: 850000, count: 85, return 2.75%
# Month: 201703, total cash: 209946.62, cash spent: 210000, count: 21, return -0.03%
# Month: 201704, total cash: 440165.28, cash spent: 440000, count: 44, return 0.04%
# Month: 201705, total cash: 804944.03, cash spent: 790000, count: 79, return 1.89%
# Month: 201706, total cash: 139907.96, cash spent: 140000, count: 14, return -0.07%
# Month: 201707, total cash: 277584.6, cash spent: 270000, count: 27, return 2.81%
# Month: 201708, total cash: 797094.8, cash spent: 780000, count: 78, return 2.19%
# Month: 201709, total cash: 97681.84, cash spent: 100000, count: 10, return -2.32%
# Month: 201710, total cash: 412140.4, cash spent: 380000, count: 38, return 8.46%
# Month: 201711, total cash: 589268.73, cash spent: 580000, count: 58, return 1.6%
# Month: 201712, total cash: 84547.94, cash spent: 80000, count: 8, return 5.68%
# Month: 201801, total cash: 100017.35, cash spent: 100000, count: 10, return 0.02%
# Month: 201802, total cash: 944229.3, cash spent: 900000, count: 90, return 4.91%
# Month: 201803, total cash: 190622.47, cash spent: 200000, count: 20, return -4.69%
# Month: 201804, total cash: 377327.17, cash spent: 380000, count: 38, return -0.7%
# Month: 201805, total cash: 1098745.54, cash spent: 1090000, count: 109, return 0.8%
# Month: 201806, total cash: 62640.85, cash spent: 60000, count: 6, return 4.4%
# Month: 201807, total cash: 266187.21, cash spent: 270000, count: 27, return -1.41%
# Month: 201808, total cash: 813419.79, cash spent: 800000, count: 80, return 1.68%
# Month: 201809, total cash: 126034.35, cash spent: 120000, count: 12, return 5.03%
# Month: 201810, total cash: 155539.18, cash spent: 160000, count: 16, return -2.79%
# Month: 201811, total cash: 264267.83, cash spent: 300000, count: 30, return -11.91%
# Month: 201812, total cash: 72778.33, cash spent: 70000, count: 7, return 3.97%
# Month: 201901, total cash: 0, cash spent: 0, count: 0 return 0
# Month: 201902, total cash: 861775.89, cash spent: 780000, count: 78, return 10.48%
# Month: 201903, total cash: 157197.32, cash spent: 150000, count: 15, return 4.8%
# Month: 201904, total cash: 203232.15, cash spent: 200000, count: 20, return 1.62%
# Month: 201905, total cash: 763545.7, cash spent: 730000, count: 73, return 4.6%
# Month: 201906, total cash: 35502.94, cash spent: 40000, count: 4, return -11.24%
# Month: 201907, total cash: 374709.26, cash spent: 350000, count: 35, return 7.06%
# Month: 201908, total cash: 518663.57, cash spent: 510000, count: 51, return 1.7%
# Month: 201909, total cash: 55837.01, cash spent: 60000, count: 6, return -6.94%
# Month: 201910, total cash: 367924.93, cash spent: 350000, count: 35, return 5.12%
# Month: 201911, total cash: 432613.57, cash spent: 430000, count: 43, return 0.61%
# Month: 201912, total cash: 122084.24, cash spent: 120000, count: 12, return 1.74%
# Month: 202001, total cash: 91757.78, cash spent: 90000, count: 9, return 1.95%
# Month: 202002, total cash: 812782.05, cash spent: 850000, count: 85, return -4.38%
# Month: 202003, total cash: 164036.46, cash spent: 190000, count: 19, return -13.67%
# Month: 202004, total cash: 139491.44, cash spent: 170000, count: 17, return -17.95%
# Month: 202005, total cash: 378887.01, cash spent: 310000, count: 31, return 22.22%
# Month: 202006, total cash: 53200.04, cash spent: 50000, count: 5, return 6.4%
# Month: 202007, total cash: 371527.07, cash spent: 370000, count: 37, return 0.41%
# Month: 202008, total cash: 348035.94, cash spent: 340000, count: 34, return 2.36%
# Month: 202009, total cash: 105463.2, cash spent: 100000, count: 10, return 5.46%
# Month: 202010, total cash: 634281.45, cash spent: 640000, count: 64, return -0.89%
# Month: 202011, total cash: 690994.92, cash spent: 670000, count: 67, return 3.13%
# Month: 202012, total cash: 171018.82, cash spent: 140000, count: 14, return 22.16%
# Month: 202101, total cash: 157159.52, cash spent: 150000, count: 15, return 4.77%
# Month: 202102, total cash: 1301146.01, cash spent: 1300000, count: 130, return 0.09%
# Month: 202103, total cash: 272479.39, cash spent: 250000, count: 25, return 8.99%
# Month: 202104, total cash: 1048153.9, cash spent: 990000, count: 99, return 5.87%
# Month: 202105, total cash: 1151798.66, cash spent: 1110000, count: 111, return 3.77%
# Month: 202106, total cash: 143483.42, cash spent: 140000, count: 14, return 2.49%
# Month: 202107, total cash: 560868.16, cash spent: 570000, count: 57, return -1.6%
# Month: 202108, total cash: 1117108.4, cash spent: 1120000, count: 112, return -0.26%
# Month: 202109, total cash: 148767.68, cash spent: 140000, count: 14, return 6.26%
# Month: 202110, total cash: 218697.23, cash spent: 230000, count: 23, return -4.91%
# Month: 202111, total cash: 556390.58, cash spent: 530000, count: 53, return 4.98%
# Month: 202112, total cash: 51584.81, cash spent: 50000, count: 5, return 3.17%
# Month: 202201, total cash: 44051.8, cash spent: 40000, count: 4, return 10.13%
# Month: 202202, total cash: 878724.02, cash spent: 920000, count: 92, return -4.49%
# Month: 202203, total cash: 301207.34, cash spent: 310000, count: 31, return -2.84%
# Month: 202204, total cash: 442748.93, cash spent: 420000, count: 42, return 5.42%
# Month: 202205, total cash: 991930.74, cash spent: 1060000, count: 106, return -6.42%
# Month: 202206, total cash: 79768.11, cash spent: 80000, count: 8, return -0.29%
# Month: 202207, total cash: 303318.79, cash spent: 330000, count: 33, return -8.09%
# Month: 202208, total cash: 838351.54, cash spent: 760000, count: 76, return 10.31%
# Month: 202209, total cash: 103401.98, cash spent: 100000, count: 10, return 3.4%
# Month: 202210, total cash: 225854.95, cash spent: 250000, count: 25, return -9.66%
# Month: 202211, total cash: 693993.5, cash spent: 610000, count: 61, return 13.77%
# Month: 202212, total cash: 122943.24, cash spent: 110000, count: 11, return 11.77%
# Month: 202301, total cash: 78065.85, cash spent: 80000, count: 8, return -2.42%
# Month: 202302, total cash: 1304175.91, cash spent: 1200000, count: 120, return 8.68%
# Month: 202303, total cash: 430895.86, cash spent: 440000, count: 44, return -2.07%
# Month: 202304, total cash: 453439.59, cash spent: 460000, count: 46, return -1.43%
# Month: 202305, total cash: 891577.72, cash spent: 910000, count: 91, return -2.02%
# Month: 202306, total cash: 85329.01, cash spent: 90000, count: 9, return -5.19%
# Month: 202307, total cash: 440184.46, cash spent: 410000, count: 41, return 7.36%
# Month: 202308, total cash: 824179.48, cash spent: 790000, count: 79, return 4.33%
# Month: 202309, total cash: 89444.7, cash spent: 90000, count: 9, return -0.62%
# Month: 202310, total cash: 286402.61, cash spent: 300000, count: 30, return -4.53%
# Month: 202311, total cash: 617003.74, cash spent: 660000, count: 66, return -6.51%
# Month: 202312, total cash: 99247.79, cash spent: 90000, count: 9, return 10.28%
# Month: 202401, total cash: 140993.07, cash spent: 130000, count: 13, return 8.46%
# Month: 202402, total cash: 1033982.48, cash spent: 1060000, count: 106, return -2.45%
# Month: 202403, total cash: 215829.42, cash spent: 210000, count: 21, return 2.78%
# Month: 202404, total cash: 536432.72, cash spent: 500000, count: 50, return 7.29%
# Month: 202405, total cash: 944087.01, cash spent: 990000, count: 99, return -4.64%
# Month: 202406, total cash: 97534.46, cash spent: 90000, count: 9, return 8.37%
# Month: 202407, total cash: 253793.46, cash spent: 260000, count: 26, return -2.39%
# Month: 202408, total cash: 639892.75, cash spent: 600000, count: 60, return 6.65%
# Month: 202409, total cash: 65614.53, cash spent: 60000, count: 6, return 9.36%
# Month: 202410, total cash: 297888.5, cash spent: 290000, count: 29, return 2.72%
# Month: 202411, total cash: 408134.07, cash spent: 420000, count: 42, return -2.83%
# Month: 202412, total cash: 70147.84, cash spent: 70000, count: 7, return 0.21%
# Final cash after all months: 23095724.124290284
